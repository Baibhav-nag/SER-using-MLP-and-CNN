# %%
import librosa
import os
import pandas as pd
import glob
import numpy as np
import soundfile
from sklearn.model_selection import train_test_split

# %%
def extract_feature(file_name,mfcc,chroma,mel,zcr,rmse):
    with soundfile.SoundFile(file_name) as sound_file:
        X = sound_file.read(dtype="float32")
        sample_rate=sound_file.samplerate
        stft=np.abs(librosa.stft(X))
        result=np.array([])
        if mfcc:
            mfccs=np.mean(librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=40).T,axis=0)
            result=np.hstack((result, mfccs))
        if chroma:
            chroma=np.mean(librosa.feature.chroma_stft(S=stft, sr=sample_rate).T,axis=0)
            result=np.hstack((result, chroma))
        if mel:
            mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
            result=np.hstack((result, mel))
        if zcr:
            zcr=np.mean(librosa.feature.zero_crossing_rate(y=X, frame_length=2048, hop_length=512).T,axis=0)
            result=np.hstack((result, zcr))
        if rmse:
            rmse=np.mean(librosa.feature.rms(S=stft,frame_length=2048, hop_length=512, pad_mode='reflect').T,axis=0)
            result=np.hstack((result, rmse))
    return result

# %%
#Load the data and extract features for each sound file
def load_data(test_size=0.5):
    x,y=[],[]
    for file in glob.glob("/content/drive/MyDrive/TESS Toronto emotional speech dataset/*//*"):
        file_name=os.path.basename(file)
        L=file_name.split('_')
        if L[2]=='angry.wav':
          e='angry'
        if L[2]=='disgust.wav':
          e='disgust'
        if L[2]=='fear.wav':
          e='fear'
        if L[2]=='happy.wav':
          e='happy'
        if L[2]=='neutral.wav':
          e='neutral'
        if L[2]=='ps.wav':
          e='pleasant surprised'
        if L[2]=='sad.wav':
          e='sad'
        feature=extract_feature(file,mfcc=True,chroma=True,mel=True,zcr=True,rmse=True)
        x.append(feature)
        y.append(e)
    return train_test_split(np.array(x), y, test_size=test_size)

# %%
x_train,x_test,y_train,y_test=load_data(test_size=0.5)

# %%
import librosa
# %matplotlib inline
import matplotlib.pyplot as plt
import librosa.display
from IPython.display import Audio
import numpy as np
import tensorflow as tf
from matplotlib.pyplot import specgram
import pandas as pd
from sklearn.metrics import confusion_matrix
import IPython.display as ipd  # To play sound in the notebook
import os # interface with underlying OS that python is running on
import sys
import warnings
# ignore warnings 
if not sys.warnoptions:
    warnings.simplefilter("ignore")
warnings.filterwarnings("ignore", category=DeprecationWarning)
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import tensorflow.keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, AveragePooling1D
from tensorflow.keras.layers import Input, Flatten, Dropout, Activation, BatchNormalization, Dense
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.regularizers import l2
import seaborn as sns
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import classification_report

# %%
y_train=np.array(y_train)
y_test=np.array(y_test)

# %%
# ONE HOT ENCODE THE TARGET
# CNN REQUIRES INPUT AND OUTPUT ARE NUMBERS
lb = LabelEncoder()
y_train = to_categorical(lb.fit_transform(y_train))
y_test = to_categorical(lb.fit_transform(y_test))

# %%
# RESHAPE DATA TO INCLUDE 3D TENSOR 
x_train = x_train[:,:,np.newaxis]
x_test = x_test[:,:,np.newaxis]
x_train.shape
# Out:
# (1400, 182, 1)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential, load_model

#BUILD 1D CNN LAYERS
model = tf.keras.Sequential()
model.add(layers.Conv1D(64, kernel_size=(10), activation='relu', input_shape=(x_train.shape[1],1)))
model.add(layers.Conv1D(128, kernel_size=(10),activation='relu',kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01)))
model.add(layers.MaxPooling1D(pool_size=(8)))
model.add(layers.Dropout(0.4))
model.add(layers.Conv1D(128, kernel_size=(10),activation='relu'))
model.add(layers.MaxPooling1D(pool_size=(8)))
model.add(layers.Dropout(0.4))
model.add(layers.Flatten())
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(7, activation='sigmoid'))
opt = keras.optimizers.Adam(lr=0.001)
model.compile(loss='categorical_crossentropy', optimizer=opt,metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_9 (Conv1D)            (None, 173, 64)           704
# _________________________________________________________________
# conv1d_10 (Conv1D)           (None, 164, 128)          82048
# _________________________________________________________________
# max_pooling1d_6 (MaxPooling1 (None, 20, 128)           0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 20, 128)           0
# _________________________________________________________________
# conv1d_11 (Conv1D)           (None, 11, 128)           163968
# _________________________________________________________________
# max_pooling1d_7 (MaxPooling1 (None, 1, 128)            0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 1, 128)            0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 7)                 1799
# =================================================================
# Total params: 281,543
# Trainable params: 281,543
# Non-trainable params: 0
# _________________________________________________________________

# %%
import tensorflow.keras as keras
model_history=model.fit(x_train, y_train,batch_size=128, epochs=100, validation_data=(x_test, y_test))
# Out:
# Epoch 1/100
# 11/11 [==============================] - 5s 397ms/step - loss: 2.9961 - accuracy: 0.1954 - val_loss: 2.3093 - val_accuracy: 0.5800
# Epoch 2/100
# 11/11 [==============================] - 4s 374ms/step - loss: 2.3449 - accuracy: 0.3773 - val_loss: 1.8119 - val_accuracy: 0.7386
# Epoch 3/100
# 11/11 [==============================] - 4s 373ms/step - loss: 1.8972 - accuracy: 0.5224 - val_loss: 1.3321 - val_accuracy: 0.8607
# Epoch 4/100
# 11/11 [==============================] - 4s 375ms/step - loss: 1.5103 - accuracy: 0.6608 - val_loss: 0.9526 - val_accuracy: 0.9393
# Epoch 5/100
# 11/11 [==============================] - 4s 375ms/step - loss: 1.1605 - accuracy: 0.7688 - val_loss: 0.7576 - val_accuracy: 0.9486
# Epoch 6/100
# 11/11 [==============================] - 4s 377ms/step - loss: 0.9687 - accuracy: 0.8200 - val_loss: 0.5888 - val_accuracy: 0.9714
# Epoch 7/100
# 11/11 [==============================] - 4s 375ms/step - loss: 0.7502 - accuracy: 0.8833 - val_loss: 0.4959 - val_accuracy: 0.9814
# Epoch 8/100
# 11/11 [==============================] - 4s 379ms/step - loss: 0.6621 - accuracy: 0.8905 - val_loss: 0.4557 - val_accuracy: 0.9764
# Epoch 9/100
# 11/11 [==============================] - 4s 379ms/step - loss: 0.5935 - accuracy: 0.9144 - val_loss: 0.4009 - val_accuracy: 0.9850
# Epoch 10/100
# 11/11 [==============================] - 4s 379ms/step - loss: 0.5048 - accuracy: 0.9361 - val_loss: 0.3394 - val_accuracy: 0.9893
# Epoch 11/100
# 11/11 [==============================] - 4s 377ms/step - loss: 0.4496 - accuracy: 0.9518 - val_loss: 0.3209 - val_accuracy: 0.9843
# Epoch 12/100
# 11/11 [==============================] - 4s 376ms/step - loss: 0.3931 - accuracy: 0.9606 - val_loss: 0.2827 - val_accuracy: 0.9914
# Epoch 13/100
# 11/11 [==============================] - 4s 378ms/step - loss: 0.3482 - accuracy: 0.9723 - val_loss: 0.2630 - val_accuracy: 0.9886
# Epoch 14/100
# 11/11 [==============================] - 4s 373ms/step - loss: 0.3237 - accuracy: 0.9718 - val_loss: 0.2419 - val_accuracy: 0.9907
# Epoch 15/100
# 11/11 [==============================] - 4s 374ms/step - loss: 0.3186 - accuracy: 0.9581 - val_loss: 0.2280 - val_accuracy: 0.9886
# Epoch 16/100
# 11/11 [==============================] - 4s 372ms/step - loss: 0.2699 - accuracy: 0.9762 - val_loss: 0.2181 - val_accuracy: 0.9893
# Epoch 17/100
# 11/11 [==============================] - 4s 372ms/step - loss: 0.2626 - accuracy: 0.9743 - val_loss: 0.1971 - val_accuracy: 0.9886
# Epoch 18/100
# 11/11 [==============================] - 4s 377ms/step - loss: 0.2256 - accuracy: 0.9784 - val_loss: 0.1852 - val_accuracy: 0.9929
# Epoch 19/100
# 11/11 [==============================] - 4s 377ms/step - loss: 0.2267 - accuracy: 0.9674 - val_loss: 0.1770 - val_accuracy: 0.9900
# Epoch 20/100
# 11/11 [==============================] - 4s 376ms/step - loss: 0.2062 - accuracy: 0.9769 - val_loss: 0.1711 - val_accuracy: 0.9900
# Epoch 21/100
# 11/11 [==============================] - 4s 376ms/step - loss: 0.1966 - accuracy: 0.9798 - val_loss: 0.1735 - val_accuracy: 0.9907
# Epoch 22/100
# 11/11 [==============================] - 4s 374ms/step - loss: 0.1990 - accuracy: 0.9777 - val_loss: 0.1558 - val_accuracy: 0.9886
# Epoch 23/100
# 11/11 [==============================] - 4s 374ms/step - loss: 0.1798 - accuracy: 0.9828 - val_loss: 0.1659 - val_accuracy: 0.9879
# Epoch 24/100
# 11/11 [==============================] - 4s 374ms/step - loss: 0.1731 - accuracy: 0.9849 - val_loss: 0.1535 - val_accuracy: 0.9907
# Epoch 25/100
# 11/11 [==============================] - 4s 374ms/step - loss: 0.1671 - accuracy: 0.9836 - val_loss: 0.1518 - val_accuracy: 0.9929
# Epoch 26/100
# 11/11 [==============================] - 4s 375ms/step - loss: 0.1596 - accuracy: 0.9812 - val_loss: 0.1461 - val_accuracy: 0.9886
# Epoch 27/100
# 11/11 [==============================] - 4s 376ms/step - loss: 0.1652 - accuracy: 0.9773 - val_loss: 0.1412 - val_accuracy: 0.9929
# Epoch 28/100
# 11/11 [==============================] - 4s 374ms/step - loss: 0.1675 - accuracy: 0.9808 - val_loss: 0.1360 - val_accuracy: 0.9921
# Epoch 29/100
# 11/11 [==============================] - 4s 374ms/step - loss: 0.1348 - accuracy: 0.9903 - val_loss: 0.1299 - val_accuracy: 0.9921
# Epoch 30/100
# 11/11 [==============================] - 4s 374ms/step - loss: 0.1265 - accuracy: 0.9935 - val_loss: 0.1309 - val_accuracy: 0.9900
# Epoch 31/100
# 11/11 [==============================] - 4s 376ms/step - loss: 0.1169 - accuracy: 0.9922 - val_loss: 0.1188 - val_accuracy: 0.9936
# Epoch 32/100
# 11/11 [==============================] - 4s 376ms/step - loss: 0.
100
# 11/11 [==============================] - 4s 375ms/step - loss: 0.1675 - accuracy: 0.9642 - val_loss: 0.1290 - val_accuracy: 0.9907
# Epoch 88/100
# 11/11 [==============================] - 4s 375ms/step - loss: 0.1372 - accuracy: 0.9771 - val_loss: 0.1454 - val_accuracy: 0.9893
# Epoch 89/100
# 11/11 [==============================] - 4s 373ms/step - loss: 0.1716 - accuracy: 0.9772 - val_loss: 0.1171 - val_accuracy: 0.9929
# Epoch 90/100
# 11/11 [==============================] - 4s 373ms/step - loss: 0.1329 - accuracy: 0.9868 - val_loss: 0.1215 - val_accuracy: 0.9943
# Epoch 91/100
# 11/11 [==============================] - 4s 377ms/step - loss: 0.1068 - accuracy: 0.9950 - val_loss: 0.1168 - val_accuracy: 0.9936
# Epoch 92/100
# 11/11 [==============================] - 4s 377ms/step - loss: 0.1050 - accuracy: 0.9933 - val_loss: 0.1207 - val_accuracy: 0.9929
# Epoch 93/100
# 11/11 [==============================] - 4s 377ms/step - loss: 0.0965 - accuracy: 0.9942 - val_loss: 0.1079 - val_accuracy: 0.9936
# Epoch 94/100
# 11/11 [==============================] - 4s 378ms/step - loss: 0.0857 - accuracy: 0.9986 - val_loss: 0.1090 - val_accuracy: 0.9921
# Epoch 95/100
# 11/11 [==============================] - 4s 377ms/step - loss: 0.1159 - accuracy: 0.9860 - val_loss: 0.0963 - val_accuracy: 0.9921
# Epoch 96/100
# 11/11 [==============================] - 4s 375ms/step - loss: 0.0848 - accuracy: 0.9964 - val_loss: 0.1034 - val_accuracy: 0.9929
# Epoch 97/100
# 11/11 [==============================] - 4s 373ms/step - loss: 0.0820 - accuracy: 0.9957 - val_loss: 0.1002 - val_accuracy: 0.9936
# Epoch 98/100
# 11/11 [==============================] - 4s 373ms/step - loss: 0.0699 - accuracy: 0.9970 - val_loss: 0.1009 - val_accuracy: 0.9936
# Epoch 99/100
# 11/11 [==============================] - 4s 372ms/step - loss: 0.0663 - accuracy: 0.9959 - val_loss: 0.0855 - val_accuracy: 0.9936
# Epoch 100/100
# 11/11 [==============================] - 4s 369ms/step - loss: 0.0656 - accuracy: 0.9938 - val_loss: 0.0900 - val_accuracy: 0.9936

# %%
# PRINT LOSS AND ACCURACY PERCENTAGE ON TEST SET
print("Loss of the model is - " , model.evaluate(x_test,y_test)[0])
print("Accuracy of the model is - " , model.evaluate(x_test,y_test)[1]*100 , "%")
# Out:
# 44/44 [==============================] - 1s 19ms/step - loss: 0.0900 - accuracy: 0.9936
# Loss of the model is -  0.08996660262346268
# 44/44 [==============================] - 1s 19ms/step - loss: 0.0900 - accuracy: 0.9936
# Accuracy of the model is -  99.3571400642395 %

# %%
predictions = model.predict(x_test)
predictions = predictions.argmax(axis=1)
predictions = predictions.astype(int).flatten()
predictions = (lb.inverse_transform((predictions)))
actual = y_test.argmax(axis=1)
actual = actual.astype(int).flatten()
actual = (lb.inverse_transform((actual)))
cm = confusion_matrix(actual, predictions,normalize='true')
plt.figure(figsize = (12, 10))
conf_matrix= pd.DataFrame(cm,columns=None)
conf_matrix.to_csv(r'E:\confusion_matrix.csv', index = False, header=False)
ax = sns.heatmap(cm, linecolor='white', cmap='Blues', linewidth=1, annot=True, fmt='')
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
plt.title('Confusion Matrix', size=20)
plt.xlabel('Predicted Labels', size=14)
plt.ylabel('Actual Labels', size=14)
plt.savefig('Initial_Model_Confusion_Matrix.png')
plt.show()

# %%
print(classification_report(actual, predictions, target_names = ['angry','disgust','fear','happy','neutral','pleasant surprised','sad']))
# Out:
#                     precision    recall  f1-score   support
#
#              angry       1.00      1.00      1.00       210
#            disgust       1.00      1.00      1.00       201
#               fear       1.00      0.99      1.00       194
#              happy       0.98      1.00      0.99       214
#            neutral       0.99      1.00      0.99       192
# pleasant surprised       1.00      0.97      0.98       209
#                sad       0.99      1.00      1.00       180
#
#           accuracy                           0.99      1400
#          macro avg       0.99      0.99      0.99      1400
#       weighted avg       0.99      0.99      0.99      1400

# %%
from imblearn.metrics import specificity_score
s=specificity_score(actual,predictions,average='macro')
print(s)
from sklearn.metrics import roc_auc_score
y_score=model.predict(x_test)
auc=roc_auc_score(y_test, y_score, average='macro',multi_class='ovo')
print(auc)
# Out:
# 0.998924974110113
# 0.9992197529762282

# %%
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
p=precision_score(actual,predictions,average='macro')
r=recall_score(actual,predictions,average='macro')
f=f1_score(actual,predictions,average='macro')
print(p,r,f)
# Out:
# 0.9937691877847452 0.9937986618709044 0.9937167988164113

# %%
FP = cm.sum(axis=0) - np.diag(cm)  
FN = cm.sum(axis=1) - np.diag(cm)
TP = np.diag(cm)
TN = cm.sum() - (FP + FN + TP)

FP = FP.astype(float)
FN = FN.astype(float)
TP = TP.astype(float)
TN = TN.astype(float)

# Sensitivity, hit rate, recall, or true positive rate
TPR = TP/(TP+FN)
# Fall out or false positive rate
FPR = FP/(FP+TN)
print(TPR)
print(FPR)
# Out:
# [0.9952381  1.         0.99484536 1.         1.         0.96650718
#  1.        ]
# [0.         0.00079745 0.         0.00398344 0.0015949  0.
#  0.00085911]

# %%
l=[]
for i in range(100):
  l.append(i+1)

# %%
from pandas import DataFrame
C = {'epoch no':l,
    'acc train':model_history.history['accuracy'],
    'acc val':model_history.history['val_accuracy'],
    'loss train':model_history.history['loss'],
    'loss val':model_history.history['val_loss']}
df = DataFrame(C, columns= ['epoch no','acc train','acc val','loss train','loss val'])
export_csv = df.to_csv (r'E:\result1.csv', index = None, header=True) 
print (df)
# Out:
#     epoch no  acc train   acc val  loss train  loss val
# 0          1   0.232143  0.580000    2.779000  2.309317
# 1          2   0.407857  0.738571    2.250759  1.811874
# 2          3   0.566429  0.860714    1.794682  1.332094
# 3          4   0.675000  0.939286    1.427154  0.952560
# 4          5   0.768571  0.948571    1.135170  0.757649
# ..       ...        ...       ...         ...       ...
# 95        96   0.996429  0.992857    0.083791  0.103409
# 96        97   0.995000  0.993571    0.079678  0.100194
# 97        98   0.996429  0.993571    0.069270  0.100881
# 98        99   0.995714  0.993571    0.068947  0.085485
# 99       100   0.995714  0.993571    0.061401  0.089967
#
# [100 rows x 5 columns]

# %%
from pandas import DataFrame
C = {
     'train acc':[str(model_history.history['accuracy'][99])],
     'test acc':[str(model_history.history['val_accuracy'][99])],
     'precision(macro)':[str(p)],
     'recall(macro)':[str(r)],
     'f1(macro)':[str(f)],
     'specificity(macro)':[str(s)],
     'AUC(macro)':[str(auc)],
     'train time per epoch':['4 sec'],
     'test time per epoch':['4 sec'],}
df = DataFrame(C, columns= ['train acc','test acc','precision(macro)','recall(macro)','f1(macro)','specificity(macro)','AUC(macro)','train time per epoch','test time per epoch'])
export_csv = df.to_csv (r'E:\result2.csv', index = None, header=True) 
print (df)
# Out:
#             train acc  ... test time per epoch
# 0  0.9957143068313599  ...               4 sec
#
# [1 rows x 9 columns]

# %%
from pandas import DataFrame
C = {
     'TPR': TPR,
     'FPR': FPR}
df = DataFrame(C, columns= ['TPR','FPR'])
export_csv = df.to_csv (r'E:\result3.csv', index = None, header=True) 
print (df)
# Out:
#         TPR       FPR
# 0  0.995238  0.000000
# 1  1.000000  0.000797
# 2  0.994845  0.000000
# 3  1.000000  0.003983
# 4  1.000000  0.001595
# 5  0.966507  0.000000
# 6  1.000000  0.000859
