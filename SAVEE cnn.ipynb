# %%
import librosa
import os
import pandas as pd
import glob
import numpy as np
import soundfile
from sklearn.model_selection import train_test_split

# %%
def extract_feature(file_name,mfcc,chroma,mel,zcr,rmse):
    with soundfile.SoundFile(file_name) as sound_file:
        X = sound_file.read(dtype="float32")
        sample_rate=sound_file.samplerate
        stft=np.abs(librosa.stft(X))
        result=np.array([])
        if mfcc:
            mfccs=np.mean(librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=40).T,axis=0)
            result=np.hstack((result, mfccs))
        if chroma:
            chroma=np.mean(librosa.feature.chroma_stft(S=stft, sr=sample_rate).T,axis=0)
            result=np.hstack((result, chroma))
        if mel:
            mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
            result=np.hstack((result, mel))
        if zcr:
            zcr=np.mean(librosa.feature.zero_crossing_rate(y=X, frame_length=2048, hop_length=512).T,axis=0)
            result=np.hstack((result, zcr))
        if rmse:
            rmse=np.mean(librosa.feature.rms(S=stft,frame_length=2048, hop_length=512, pad_mode='reflect').T,axis=0)
            result=np.hstack((result, rmse))
    return result

# %%
#Load the data and extract features for each sound file
def load_data(test_size=0.2):
    x,y=[],[]
    for file in glob.glob("/content/drive/MyDrive/SAVEE dataset/Actor_*//*.wav"):
        file_name=os.path.basename(file)
        emotion=file_name[0]
        if emotion=='a':
          e='anger'
        if emotion=='d':
          e='disgust'
        if emotion=='f':
          e='fear'
        if emotion=='h':
          e='happy'
        if emotion=='n':
          e='neutral'
        if emotion=='s':
          if file_name[1]=='a':
            e='sad'
          else:
            e='surprise'
        feature=extract_feature(file,mfcc=True,chroma=True,mel=True,zcr=True,rmse=True)
        x.append(feature)
        y.append(e)
    return train_test_split(np.array(x), y, test_size=test_size)

# %%
x_train,x_test,y_train,y_test=load_data(test_size=0.2)

# %%
import librosa
# %matplotlib inline
import matplotlib.pyplot as plt
import librosa.display
from IPython.display import Audio
import numpy as np
import tensorflow as tf
from matplotlib.pyplot import specgram
import pandas as pd
from sklearn.metrics import confusion_matrix
import IPython.display as ipd  # To play sound in the notebook
import os # interface with underlying OS that python is running on
import sys
import warnings
# ignore warnings 
if not sys.warnoptions:
    warnings.simplefilter("ignore")
warnings.filterwarnings("ignore", category=DeprecationWarning)
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import tensorflow.keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, AveragePooling1D
from tensorflow.keras.layers import Input, Flatten, Dropout, Activation, BatchNormalization, Dense
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.regularizers import l2
import seaborn as sns
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import classification_report

# %%
y_train=np.array(y_train)
y_test=np.array(y_test)

# %%
# ONE HOT ENCODE THE TARGET
# CNN REQUIRES INPUT AND OUTPUT ARE NUMBERS
lb = LabelEncoder()
y_train = to_categorical(lb.fit_transform(y_train))
y_test = to_categorical(lb.fit_transform(y_test))

# %%
# RESHAPE DATA TO INCLUDE 3D TENSOR 
x_train = x_train[:,:,np.newaxis]
x_test = x_test[:,:,np.newaxis]
x_train.shape
# Out:
# (384, 182, 1)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential, load_model

#BUILD 1D CNN LAYERS
model = tf.keras.Sequential()
model.add(layers.Conv1D(64, kernel_size=(10), activation='relu', input_shape=(x_train.shape[1],1)))
model.add(layers.Conv1D(128, kernel_size=(10),activation='relu',kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01)))
model.add(layers.MaxPooling1D(pool_size=(8)))
model.add(layers.Dropout(0.4))
model.add(layers.Conv1D(128, kernel_size=(10),activation='relu'))
model.add(layers.MaxPooling1D(pool_size=(8)))
model.add(layers.Dropout(0.4))
model.add(layers.Flatten())
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(7, activation='sigmoid'))
opt = keras.optimizers.Adam(lr=0.001)
model.compile(loss='categorical_crossentropy', optimizer=opt,metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_3 (Conv1D)            (None, 173, 64)           704
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 164, 128)          82048
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 20, 128)           0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 20, 128)           0
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 11, 128)           163968
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 1, 128)            0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 1, 128)            0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 7)                 1799
# =================================================================
# Total params: 281,543
# Trainable params: 281,543
# Non-trainable params: 0
# _________________________________________________________________

# %%
import tensorflow.keras as keras
model_history=model.fit(x_train, y_train,batch_size=128, epochs=100, validation_data=(x_test, y_test))
# Out:
# Epoch 1/100
# 3/3 [==============================] - 2s 491ms/step - loss: 6.7597 - accuracy: 0.1374 - val_loss: 3.3713 - val_accuracy: 0.2708
# Epoch 2/100
# 3/3 [==============================] - 1s 386ms/step - loss: 4.2017 - accuracy: 0.2243 - val_loss: 2.7648 - val_accuracy: 0.3125
# Epoch 3/100
# 3/3 [==============================] - 1s 383ms/step - loss: 3.2127 - accuracy: 0.2357 - val_loss: 2.6026 - val_accuracy: 0.3438
# Epoch 4/100
# 3/3 [==============================] - 1s 392ms/step - loss: 2.8875 - accuracy: 0.2611 - val_loss: 2.5939 - val_accuracy: 0.2917
# Epoch 5/100
# 3/3 [==============================] - 1s 381ms/step - loss: 2.7045 - accuracy: 0.2913 - val_loss: 2.5604 - val_accuracy: 0.3229
# Epoch 6/100
# 3/3 [==============================] - 1s 381ms/step - loss: 2.6397 - accuracy: 0.2640 - val_loss: 2.5265 - val_accuracy: 0.3438
# Epoch 7/100
# 3/3 [==============================] - 1s 384ms/step - loss: 2.6083 - accuracy: 0.3158 - val_loss: 2.4978 - val_accuracy: 0.3125
# Epoch 8/100
# 3/3 [==============================] - 1s 381ms/step - loss: 2.5576 - accuracy: 0.3197 - val_loss: 2.4694 - val_accuracy: 0.3125
# Epoch 9/100
# 3/3 [==============================] - 1s 377ms/step - loss: 2.5149 - accuracy: 0.3385 - val_loss: 2.4368 - val_accuracy: 0.3229
# Epoch 10/100
# 3/3 [==============================] - 1s 380ms/step - loss: 2.4692 - accuracy: 0.3252 - val_loss: 2.3942 - val_accuracy: 0.3750
# Epoch 11/100
# 3/3 [==============================] - 1s 379ms/step - loss: 2.4310 - accuracy: 0.3851 - val_loss: 2.3624 - val_accuracy: 0.3542
# Epoch 12/100
# 3/3 [==============================] - 1s 378ms/step - loss: 2.3884 - accuracy: 0.3880 - val_loss: 2.3289 - val_accuracy: 0.3750
# Epoch 13/100
# 3/3 [==============================] - 1s 382ms/step - loss: 2.3714 - accuracy: 0.3577 - val_loss: 2.2874 - val_accuracy: 0.3750
# Epoch 14/100
# 3/3 [==============================] - 1s 378ms/step - loss: 2.3694 - accuracy: 0.3548 - val_loss: 2.2552 - val_accuracy: 0.3646
# Epoch 15/100
# 3/3 [==============================] - 1s 379ms/step - loss: 2.2951 - accuracy: 0.3675 - val_loss: 2.2242 - val_accuracy: 0.3646
# Epoch 16/100
# 3/3 [==============================] - 1s 382ms/step - loss: 2.2625 - accuracy: 0.3672 - val_loss: 2.1974 - val_accuracy: 0.3438
# Epoch 17/100
# 3/3 [==============================] - 1s 384ms/step - loss: 2.3142 - accuracy: 0.3620 - val_loss: 2.1588 - val_accuracy: 0.3646
# Epoch 18/100
# 3/3 [==============================] - 1s 385ms/step - loss: 2.1736 - accuracy: 0.3870 - val_loss: 2.1340 - val_accuracy: 0.4062
# Epoch 19/100
# 3/3 [==============================] - 1s 383ms/step - loss: 2.2258 - accuracy: 0.3672 - val_loss: 2.1173 - val_accuracy: 0.3958
# Epoch 20/100
# 3/3 [==============================] - 1s 378ms/step - loss: 2.1198 - accuracy: 0.3984 - val_loss: 2.0873 - val_accuracy: 0.4271
# Epoch 21/100
# 3/3 [==============================] - 1s 380ms/step - loss: 2.1445 - accuracy: 0.3506 - val_loss: 2.0522 - val_accuracy: 0.4062
# Epoch 22/100
# 3/3 [==============================] - 1s 385ms/step - loss: 2.0318 - accuracy: 0.4271 - val_loss: 2.0098 - val_accuracy: 0.4167
# Epoch 23/100
# 3/3 [==============================] - 1s 384ms/step - loss: 2.0952 - accuracy: 0.3861 - val_loss: 1.9711 - val_accuracy: 0.4375
# Epoch 24/100
# 3/3 [==============================] - 1s 379ms/step - loss: 2.0279 - accuracy: 0.4245 - val_loss: 1.9465 - val_accuracy: 0.4167
# Epoch 25/100
# 3/3 [==============================] - 1s 385ms/step - loss: 1.9905 - accuracy: 0.4551 - val_loss: 1.9299 - val_accuracy: 0.4271
# Epoch 26/100
# 3/3 [==============================] - 1s 378ms/step - loss: 1.9543 - accuracy: 0.4320 - val_loss: 1.9155 - val_accuracy: 0.4479
# Epoch 27/100
# 3/3 [==============================] - 1s 380ms/step - loss: 1.9505 - accuracy: 0.4310 - val_loss: 1.8960 - val_accuracy: 0.4688
# Epoch 28/100
# 3/3 [==============================] - 1s 380ms/step - loss: 1.9029 - accuracy: 0.4775 - val_loss: 1.8555 - val_accuracy: 0.4688
# Epoch 29/100
# 3/3 [==============================] - 1s 382ms/step - loss: 1.8906 - accuracy: 0.4395 - val_loss: 1.8311 - val_accuracy: 0.4479
# Epoch 30/100
# 3/3 [==============================] - 1s 388ms/step - loss: 1.9306 - accuracy: 0.4147 - val_loss: 1.8202 - val_accuracy: 0.4688
# Epoch 31/100
# 3/3 [==============================] - 1s 384ms/step - loss: 1.7919 - accuracy: 0.4359 - val_loss: 1.8023 - val_accuracy: 0.4688
# Epoch 32/100
# 3/3 [==============================] - 1s 381ms/step - loss: 1.8301 - accuracy: 0.4577 - val_loss: 1.7986 - val_accuracy: 0.4688
# Epoch 33/100
# 3/3 [==============================] - 1s 384ms/step - loss: 1.7970 - accuracy: 0.4720 - val_loss: 1.7827 - val_accuracy: 0.4688
# Epoch 34/100
# 3/3 [==============================] - 1s 378ms/step - loss: 1.7910 - accuracy: 0.4632 - val_loss: 1.7670 - val_accuracy: 0.4479
# Epoch 35/100
# 3/3 [==============================] - 1s 381ms/step - loss: 1.8393 - accuracy: 0.4378 - val_loss: 1.7587 - val_accuracy: 0.4479
# Epoch 36/100
# 3/3 [==============================] - 1s 387ms/step - loss: 1.7935 - accuracy: 0.4495 - val_loss: 1.7683 - val_accuracy: 0.4583
# Epoch 37/100
# 3/3 [==============================] - 1s 384ms/step - loss: 1.7369 - accuracy: 0.4863 - val_loss: 1.7459 - val_accuracy: 0.4583
# Epoch 38/100
# 3/3 [==============================] - 1s 387ms/step - loss: 1.7467 - accuracy: 0.4476 - val_loss: 1.7071 - val_accuracy: 0.4688
# Epoch 39/100
# 3/3 [==============================] - 1s 389ms/step - loss: 1.6603 - accuracy: 0.4772 - val_loss: 1.6902 - val_accuracy: 0.4688
# Epoch 40/100
# 3/3 [==============================] - 1s 376ms/step - loss: 1.7257 - accuracy: 0.4548 - val_loss: 1.6828 - val_accuracy: 0.4896
# Epoch 41/100
# 3/3 [==============================] - 1s 382ms/step - loss: 1.6595 - accuracy: 0.4889 - val_loss: 1.6449 - val_accuracy: 0.5000
# Epoch 42/100
# 3/3 [==============================] - 1s 383ms/step - loss: 1.6588 - accuracy: 0.4805 - val_loss: 1.6210 - val_accuracy: 0.5104
# Epoch 43/100
# 3/3 [==============================] - 1s 382ms/step - loss: 1.5990 - accuracy: 0.5150 - val_loss: 1.6282 - val_accuracy: 0.4688
# Epoch 44/100
# 3/3 [==============================] - 1s 381ms/step - loss: 1.6717 - accuracy: 0.5173 - val_loss: 1.6042 - val_accuracy: 0.4792
# Epoch 45/100
# 3/3 [==============================] - 1s 382ms/step - loss: 1.6084 - accuracy: 0.5033 - val_loss: 1.6105 - val_accuracy: 0.4896
# Epoch 46/100
# 3/3 [==============================] - 1s 384ms/step - loss: 1.5705 - accuracy: 0.5221 - val_loss: 1.6282 - val_accuracy: 0.4688
# Epoch 47/100
# 3/3 [==============================] - 1s 381ms/step - loss: 1.5268 - accuracy: 0.5420 - val_loss: 1.5752 - val_accuracy: 0.4896
# Epoch 48/100
# 3/3 [==============================] - 1s 388ms/step - loss: 1.5124 - accuracy: 0.5553 - val_loss: 1.6117 - val_accuracy: 0.5000
# Epoch 49/100
# 3/3 [==============================] - 1s 385ms/step - loss: 1.5236 - accuracy: 0.5680 - val_loss: 1.5828 - val_accuracy: 0.5104
# Epoch 50/100
# 3/3 [==============================] - 1s 382ms/step - loss: 1.5659 - accuracy: 0.4941 - val_loss: 1.5735 - val_accuracy: 0.5521
# Epoch 51/100
# 3/3 [==============================] - 1s 380ms/step - loss: 1.5526 - accuracy: 0.5124 - val_loss: 1.6029 - val_accuracy: 0.4792
# Epoch 52/100
# 3/3 [==============================] - 1s 384ms/step - loss: 1.5076 - accuracy: 0.5671 - val_loss: 1.5149 - val_accuracy: 0.5729
# Epoch 53/100
# 3/3 [==============================] - 1s 384ms/step - loss: 1.5308 - accuracy: 0.5117 - val_loss: 1.4934 - val_accuracy: 0.5208
# Epoch 54/100
# 3/3 [==============================] - 1s 385ms/step - loss: 1.4428 - accuracy: 0.5661 - val_loss: 1.5734 - val_accuracy: 0.5104
# Epoch 55/100
# 3/3 [==============================] - 1s 384ms/step - loss: 1.4082 - accuracy: 0.5817 - val_loss: 1.5221 - val_accuracy: 0.5417
# Epoch 56/100
# 3/3 [==============================] - 1s 381ms/step - loss: 1.4142 - accuracy: 0.6025 - val_loss: 1.4817 - val_accuracy: 0.5521
# Epoch 57/100
# 3/3 [==============================] - 1s 380ms/step - loss: 1.4571 - accuracy: 0.5452 - val_loss: 1.5120 - val_accuracy: 0.5625
# Epoch 58/100
# 3/3 [==============================] - 1s 391ms/step - loss: 1.3827 - accuracy: 0.6006 - val_loss: 1.5108 - val_accuracy: 0.5521
# Epoch 59/100
# 3/3 [==============================] - 1s 382ms/step - loss: 1.3604 - accuracy: 0.5856 - val_loss: 1.5151 - val_accuracy: 0.5625
# Epoch 60/100
# 3/3 [==============================] - 1s 380ms/step - loss: 1.4061 - accuracy: 0.5781 - val_loss: 1.4834 - val_accuracy: 0.5521
# Epoch 61/100
# 3/3 [==============================] - 1s 382ms/step - loss: 1.3567 - accuracy: 0.5960 - val_loss: 1.4146 - val_accuracy: 0.5833
# Epoch 62/100
# 3/3 [==============================] - 1s 377ms/step - loss: 1.3295 - accuracy: 0.6253 - val_loss: 1.4542 - val_accuracy: 0.5625
# Epoch 63/100
# 3/3 [==============================] - 1s 380ms/step - loss: 1.3295 - accuracy: 0.5749 - val_loss: 1.3860 - val_accuracy: 0.5938
# Epoch 64/100
# 3/3 [==============================] - 1s 387ms/step - loss: 1.3729 - accuracy: 0.5915 - val_loss: 1.4203 - val_accuracy: 0.5729
# Epoch 65/100
# 3/3 [==============================] - 1s 385ms/step - loss: 1.3414 - accuracy: 0.6143 - val_loss: 1.4074 - val_accuracy: 0.5625
# Epoch 66/100
# 3/3 [==============================] - 1s 383ms/step - loss: 1.2703 - accuracy: 0.6432 - val_loss: 1.3976 - val_accuracy: 0.5833
# Epoch 67/100
# 3/3 [==============================] - 1s 385ms/step - loss: 1.3078 - accuracy: 0.5918 - val_loss: 1.4635 - val_accuracy: 0.5521
# Epoch 68/100
# 3/3 [==============================] - 1s 380ms/step - loss: 1.2683 - accuracy: 0.6260 - val_loss: 1.4846 - val_accuracy: 0.5938
# Epoch 69/100
# 3/3 [==============================] - 1s 380ms/step - loss: 1.2438 - accuracy: 0.6090 - val_loss: 1.4231 - val_accuracy: 0.6250
# Epoch 70/100
# 3/3 [==============================] - 1s 385ms/step - loss: 1.2419 - accuracy: 0.6260 - val_loss: 1.4275 - val_accuracy: 0.5417
# Epoch 71/100
# 3/3 [==============================] - 1s 383ms/step - loss: 1.2135 - accuracy: 0.6572 - val_loss: 1.3902 - val_accuracy: 0.6146
# Epoch 72/100
# 3/3 [==============================] - 1s 384ms/step - loss: 1.2144 - accuracy: 0.6416 - val_loss: 1.3643 - val_accuracy: 0.6354
# Epoch 73/100
# 3/3 [==============================] - 1s 376ms/step - loss: 1.2329 - accuracy: 0.6296 - val_loss: 1.4035 - val_accuracy: 0.6042
# Epoch 74/100
# 3/3 [==============================] - 1s 375ms/step - loss: 1.2156 - accuracy: 0.6553 - val_loss: 1.4243 - val_accuracy: 0.6458
# Epoch 75/100
# 3/3 [==============================] - 1s 376ms/step - loss: 1.1540 - accuracy: 0.6758 - val_loss: 1.4463 - val_accuracy: 0.5625
# Epoch 76/100
# 3/3 [==============================] - 1s 387ms/step - loss: 1.1447 - accuracy: 0.6732 - val_loss: 1.4007 - val_accuracy: 0.6354
# Epoch 77/100
# 3/3 [==============================] - 1s 379ms/step - loss: 1.1830 - accuracy: 0.6689 - val_loss: 1.3663 - val_accuracy: 0.6458
# Epoch 78/100
# 3/3 [==============================] - 1s 380ms/step - loss: 1.1568 - accuracy: 0.6758 - val_loss: 1.4613 - val_accuracy: 0.5833
# Epoch 79/100
# 3/3 [==============================] - 1s 383ms/step - loss: 1.2203 - accuracy: 0.6380 - val_loss: 1.4655 - val_accuracy: 0.5938
# Epoch 80/100
# 3/3 [==============================] - 1s 383ms/step - loss: 1.1942 - accuracy: 0.6234 - val_loss: 1.4580 - val_accuracy: 0.6042
# Epoch 81/100
# 3/3 [==============================] - 1s 385ms/step - loss: 1.1860 - accuracy: 0.6543 - val_loss: 1.4122 - val_accuracy: 0.6250
# Epoch 82/100
# 3/3 [==============================] - 1s 380ms/step - loss: 1.1269 - accuracy: 0.6725 - val_loss: 1.3850 - val_accuracy: 0.5833
# Epoch 83/100
# 3/3 [==============================] - 1s 390ms/step - loss: 1.1327 - accuracy: 0.6615 - val_loss: 1.3027 - val_accuracy: 0.6667
# Epoch 84/100
# 3/3 [==============================] - 1s 383ms/step - loss: 1.1933 - accuracy: 0.6400 - val_loss: 1.3340 - val_accuracy: 0.6250
# Epoch 85/100
# 3/3 [==============================] - 1s 387ms/step - loss: 1.1150 - accuracy: 0.6706 - val_loss: 1.3546 - val_accuracy: 0.6354
# Epoch 86/100
# 3/3 [==============================] - 1s 377ms/step - loss: 1.1136 - accuracy: 0.6755 - val_loss: 1.3243 - val_accuracy: 0.6875
# Epoch 87/100
# 3/3 [==============================] - 1s 378ms/step - loss: 1.0293 - accuracy: 0.7087 - val_loss: 1.4006 - val_accuracy: 0.6146
# Epoch 88/100
# 3/3 [==============================] - 1s 381ms/step - loss: 1.0859 - accuracy: 0.6836 - val_loss: 1.3591 - val_accuracy: 0.6875
# Epoch 89/100
# 3/3 [==============================] - 1s 387ms/step - loss: 1.0823 - accuracy: 0.7109 - val_loss: 1.3743 - val_accuracy: 0.6354
# Epoch 90/100
# 3/3 [==============================] - 1s 387ms/step - loss: 1.0414 - accuracy: 0.7090 - val_loss: 1.3277 - val_accuracy: 0.6354
# Epoch 91/100
# 3/3 [==============================] - 1s 385ms/step - loss: 1.0594 - accuracy: 0.6921 - val_loss: 1.3430 - val_accuracy: 0.6250
# Epoch 92/100
# 3/3 [==============================] - 1s 382ms/step - loss: 1.0346 - accuracy: 0.7230 - val_loss: 1.3591 - val_accuracy: 0.6458
# Epoch 93/100
# 3/3 [==============================] - 1s 386ms/step - loss: 0.9999 - accuracy: 0.6787 - val_loss: 1.3207 - val_accuracy: 0.6875
# Epoch 94/100
# 3/3 [==============================] - 1s 383ms/step - loss: 0.9889 - accuracy: 0.7344 - val_loss: 1.4087 - val_accuracy: 0.6562
# Epoch 95/100
# 3/3 [==============================] - 1s 385ms/step - loss: 0.9994 - accuracy: 0.7327 - val_loss: 1.3688 - val_accuracy: 0.6250
# Epoch 96/100
# 3/3 [==============================] - 1s 382ms/step - loss: 0.9480 - accuracy: 0.7474 - val_loss: 1.3480 - val_accuracy: 0.6667
# Epoch 97/100
# 3/3 [==============================] - 1s 382ms/step - loss: 0.9510 - accuracy: 0.7275 - val_loss: 1.3314 - val_accuracy: 0.6042
# Epoch 98/100
# 3/3 [==============================] - 1s 379ms/step - loss: 0.9583 - accuracy: 0.7454 - val_loss: 1.2747 - val_accuracy: 0.6250
# Epoch 99/100
# 3/3 [==============================] - 1s 396ms/step - loss: 0.9535 - accuracy: 0.7376 - val_loss: 1.2089 - val_accuracy: 0.6562
# Epoch 100/100
# 3/3 [==============================] - 1s 384ms/step - loss: 0.9651 - accuracy: 0.6992 - val_loss: 1.2316 - val_accuracy: 0.7083

# %%
# PRINT LOSS AND ACCURACY PERCENTAGE ON TEST SET
print("Loss of the model is - " , model.evaluate(x_test,y_test)[0])
print("Accuracy of the model is - " , model.evaluate(x_test,y_test)[1]*100 , "%")
# Out:
# 3/3 [==============================] - 0s 25ms/step - loss: 1.2316 - accuracy: 0.7083
# Loss of the model is -  1.2315956354141235
# 3/3 [==============================] - 0s 24ms/step - loss: 1.2316 - accuracy: 0.7083
# Accuracy of the model is -  70.83333134651184 %

# %%
predictions = model.predict(x_test)
predictions = predictions.argmax(axis=1)
predictions = predictions.astype(int).flatten()
predictions = (lb.inverse_transform((predictions)))
actual = y_test.argmax(axis=1)
actual = actual.astype(int).flatten()
actual = (lb.inverse_transform((actual)))
cm = confusion_matrix(actual, predictions,normalize='true')
plt.figure(figsize = (12, 10))
conf_matrix= pd.DataFrame(cm,columns=None)
conf_matrix.to_csv(r'E:\confusion_matrix.csv', index = False, header=False)
ax = sns.heatmap(cm, linecolor='white', cmap='Blues', linewidth=1, annot=True, fmt='')
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
plt.title('Confusion Matrix', size=20)
plt.xlabel('Predicted Labels', size=14)
plt.ylabel('Actual Labels', size=14)
plt.savefig('Initial_Model_Confusion_Matrix.png')
plt.show()

# %%
print(classification_report(actual, predictions, target_names = ['anger','disgust','fear','happy','neutral','sad','surprise']))
# Out:
#               precision    recall  f1-score   support
#
#        anger       0.89      0.73      0.80        11
#      disgust       0.79      0.85      0.81        13
#         fear       0.88      0.50      0.64        14
#        happy       0.53      0.80      0.64        10
#      neutral       0.70      1.00      0.82        23
#          sad       1.00      0.36      0.53        14
#     surprise       0.50      0.55      0.52        11
#
#     accuracy                           0.71        96
#    macro avg       0.75      0.68      0.68        96
# weighted avg       0.76      0.71      0.69        96

# %%
from imblearn.metrics import specificity_score
s=specificity_score(actual,predictions,average='macro')
print(s)
from sklearn.metrics import roc_auc_score
y_score=model.predict(x_test)
auc=roc_auc_score(y_test, y_score, average='macro',multi_class='ovo')
print(auc)
# Out:
# 0.9501322440502836
# 0.8560866286426058

# %%
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
p=precision_score(actual,predictions,average='macro')
r=recall_score(actual,predictions,average='macro')
f=f1_score(actual,predictions,average='macro')
print(p,r,f)
# Out:
# 0.7542723149866006 0.6822891394319964 0.6800945632164985

# %%
FP = cm.sum(axis=0) - np.diag(cm)  
FN = cm.sum(axis=1) - np.diag(cm)
TP = np.diag(cm)
TN = cm.sum() - (FP + FN + TP)

FP = FP.astype(float)
FN = FN.astype(float)
TP = TP.astype(float)
TN = TN.astype(float)

# Sensitivity, hit rate, recall, or true positive rate
TPR = TP/(TP+FN)
# Fall out or false positive rate
FPR = FP/(FP+TN)
print(TPR)
print(FPR)
# Out:
# [0.72727273 0.84615385 0.5        0.8        1.         0.35714286
#  0.54545455]
# [0.01666667 0.03571429 0.01515152 0.10281385 0.12412587 0.
#  0.07619048]

# %%
l=[]
for i in range(100):
  l.append(i+1)

# %%
from pandas import DataFrame
C = {'epoch no':l,
    'acc train':model_history.history['accuracy'],
    'acc val':model_history.history['val_accuracy'],
    'loss train':model_history.history['loss'],
    'loss val':model_history.history['val_loss']}
df = DataFrame(C, columns= ['epoch no','acc train','acc val','loss train','loss val'])
export_csv = df.to_csv (r'E:\result1.csv', index = None, header=True) 
print (df)
# Out:
#     epoch no  acc train   acc val  loss train  loss val
# 0          1   0.138021  0.270833    6.153827  3.371342
# 1          2   0.223958  0.312500    4.042690  2.764760
# 2          3   0.236979  0.343750    3.122367  2.602635
# 3          4   0.260417  0.291667    2.858799  2.593868
# 4          5   0.283854  0.322917    2.724902  2.560400
# ..       ...        ...       ...         ...       ...
# 95        96   0.736979  0.666667    0.961989  1.348037
# 96        97   0.710938  0.604167    0.963336  1.331414
# 97        98   0.744792  0.625000    0.935930  1.274690
# 98        99   0.729167  0.656250    0.948140  1.208891
# 99       100   0.710938  0.708333    0.944265  1.231596
#
# [100 rows x 5 columns]

# %%
from pandas import DataFrame
C = {
     'train acc':[str(model_history.history['accuracy'][99])],
     'test acc':[str(model_history.history['val_accuracy'][99])],
     'precision(macro)':[str(p)],
     'recall(macro)':[str(r)],
     'f1(macro)':[str(f)],
     'specificity(macro)':[str(s)],
     'AUC(macro)':[str(auc)],
     'train time per epoch':['1 sec'],
     'test time per epoch':['1 sec'],}
df = DataFrame(C, columns= ['train acc','test acc','precision(macro)','recall(macro)','f1(macro)','specificity(macro)','AUC(macro)','train time per epoch','test time per epoch'])
export_csv = df.to_csv (r'E:\result2.csv', index = None, header=True) 
print (df)
# Out:
#    train acc            test acc  ... train time per epoch test time per epoch
# 0  0.7109375  0.7083333134651184  ...                1 sec               1 sec
#
# [1 rows x 9 columns]

# %%
from pandas import DataFrame
C = {
     'TPR': TPR,
     'FPR': FPR}
df = DataFrame(C, columns= ['TPR','FPR'])
export_csv = df.to_csv (r'E:\result3.csv', index = None, header=True) 
print (df)
# Out:
#         TPR       FPR
# 0  0.727273  0.016667
# 1  0.846154  0.035714
# 2  0.500000  0.015152
# 3  0.800000  0.102814
# 4  1.000000  0.124126
# 5  0.357143  0.000000
# 6  0.545455  0.076190
